# %%
import requests
from selenium import webdriver
import math

# Функция преобразования номера тайла в координаты широты и долготы
def num2deg(xtile, ytile, zoom):
    n = 2.0 ** zoom
    lon_deg = xtile / n * 360.0 - 180.0
    lat_rad = math.atan(math.sinh(math.pi * (1 - 2 * ytile / n)))
    lat_deg = math.degrees(lat_rad)
    return (lat_deg, lon_deg)

# %%
# в данном сегменте с помощью вебдрайвера открывается сайт satbeams с помощью гугла и ставится зум в значчение k(max = 7), так как нам
# нам нужны тайлы с определнным зумированием/разбиением. Далее оберну в функцию, пока тесты

import time
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://www.satbeams.com/footprints")
k = 2  
# Maximize the window and let code stall 
# for 10s to properly maximise the window.
driver.maximize_window()
time.sleep(3)
  
# Obtain button by link text and click.
button = driver.find_element_by_css_selector("#map > div.leaflet-control-container > div.leaflet-top.leaflet-left > div.leaflet-control-zoom.leaflet-bar.leaflet-control > a.leaflet-control-zoom-in")
for i in range(k):
    button.click()
    time.sleep(3)
    
# button.click()
# time.sleep(3)
# button.click()
# time.sleep(3)
page_source = driver.page_source
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 111.0.5563
# [WDM] - Get LATEST chromedriver version for 111.0.5563 google-chrome
# [WDM] - Driver [C:\Users\glebk\.wdm\drivers\chromedriver\win32\111.0.5563.64\chromedriver.exe] found in cache

# %%
page_source
# Out:
# '<html itemscope="" itemtype="http://schema.org/WebSite" class=" ext-strict"><head><style>.cesium-credit-lightbox-overlay {display: none; z-index: 1; position: absolute; top: 0; left: 0; width: 100%; height: 100%; background-color: rgba(80, 80, 80, 0.8);  }\n.cesium-credit-lightbox {background-color: #303336; color: #ffffff; position: relative; min-height: 100px; margin: auto;  }\n.cesium-credit-lightbox > ul > li a, .cesium-credit-lightbox > ul > li a:visited {color: #ffffff;  }\n.cesium-credit-lightbox > ul > li a:hover {color: #48b;  }\n.cesium-credit-lightbox.cesium-credit-lightbox-expanded {border: 1px solid #444; border-radius: 5px; max-width: 370px;  }\n.cesium-credit-lightbox.cesium-credit-lightbox-mobile {height: 100%; width: 100%;  }\n.cesium-credit-lightbox-title {padding: 20px 20px 0 20px;  }\n.cesium-credit-lightbox-close {font-size: 18pt; cursor: pointer; position: absolute; top: 0; right: 6px; color: #ffffff;  }\n.cesium-credit-lightbox-close:hover {color: #48b;  }\n.cesium-credit-lightbox > ul {margin: 0; padding: 12px 20px 12px 40px; font-size: 13px;  }\n.cesium-credit-lightbox > ul > li {padding-bottom: 6px;  }\n.cesium-credit-lightbox > ul > li * {padding: 0; margin: 0;  }\n.cesium-credit-expand-link {padding-left: 5px; cursor: pointer; text-decoration: underline; color: #ffffff;  }\n.cesium-credit-expand-link:hover {color: #48b;  }\n.cesium-credit-text {color: #ffffff;  }\n.cesium-credit-textContainer *, .cesium-credit-logoContainer * {display: inline;  }\n</style>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"> \n<!-- tags and meta data for link sharing -->\n<meta itemprop="name" content="Satbeams">\n<meta itemprop="description" content="Satbeams - World Of Satellites at your fingertips">\n<meta itemprop="image" content="http://www.satbeams.com/images/home_page/satellite.png">\n<meta property="og:title" content="Satbeams - World Of Satellites at your fingertips">\n<meta property="og:image" content="http://www.satbeams.com/images/home_page/satellite.png">\n<meta property="og:image:secure_url" content="https://www.satbeams.com/images/home_page/satellite.png">\n<meta property="og:site_name" content="Satbeams Web and Mobile">\n<meta property="og:url" content="http://www.satbeams.com/">\n<meta property="og:description" content="Satbeams - Satellite footprints, news and charts">\n<link rel="image_src" href="http://www.satbeams.com/images/home_page/satellite.png">\n<!-- /tags and meta data for link sharing -->\n<!-- Google Analytics Code -->\n<script async="" src="https://www.clarity.ms/eus-c/s/0.7.5/clarity.js"></script><script src="https://partner.googleadservices.com/gampad/cookie.js?domain=www.satbeams.com&amp;callback=_gfp_s_&amp;client=ca-pub-3103368419297659"></script><script src="https://pagead2.googlesyndication.com/pagead/managed/js/adsense/m202303210101/show_ads_impl_fy2021.js?bust=31073335" id="google_shimpl"></script><script id="facebook-jssdk" src="//connect.facebook.net/en_US/sdk.js#xfbml=1&amp;version=v2.5&amp;appId=205450589481910"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://owa.satbeams.com/modules/base/js/owa.tracker-combined-min.js"></script><script async="" src="https://www.clarity.ms/tag/cagzt7byq8"></script><script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>\n<script type="text/javascript">\nvar gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");\ndocument.write(unescape("%3Cscript src=\'" + gaJsHost + "google-analytics.com/ga.js\' type=\'text/javascript\'%3E%3C/script%3E"));\n</script><script src="https://ssl.google-analytics.com/ga.js" type="text/javascript"></script>\n<script type="text/javascript">\ntry {\nvar pageTracker = _gat._getTracker("UA-151794-5");\npageTracker._trackPageview();\n} catch(err) {}</script>\n<!-- end of Google Analytics Code -->\n<!-- Global site tag (gtag.js) - Google Analytics -->\n<script async=""  ...

# %%
# тут достаю сслыки на все спутники

import requests
from bs4 import BeautifulSoup
import numpy as np

soup = BeautifulSoup(page_source, 'html.parser')
button_next = driver.find_element_by_css_selector('#sat_bar > div:nth-child(3)')
links = soup.find_all('a', {'class':'sat_div satellite_gray'}, href=True)
hrefs = np.array([])
hr = np.array([])
a = True
while a == True:
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')
    # print(soup)    
    links = soup.find_all('a', {'class':'sat_div satellite_gray'}, href=True)
    for link in links:
        hr = np.append(hr,link.get('href'))
#         hr.append(link.get('href'))
    if all(elem in hrefs for elem in hr):
        a = False
    else:
        result = np.in1d(hr, hrefs)
        hrefs = np.append(hrefs,hr[result==False])
        
    button_next.click()
    time.sleep(1)
# divs = soup.select('div.paint')

# for div in divs:
#     print(div.text)
# Out:
# D:\anaconda\envs\MLEnv\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison

# %%
hrefs
# Out:
# array(['?position=284', '?position=285', '?position=286', '?position=287',
#        '?position=288', '?position=290', '?position=293', '?position=295',
#        '?position=297', '?position=299', '?position=302', '?position=305',
#        '?position=306', '?position=307', '?position=310', '?position=313',
#        '?position=315', '?position=317', '?position=320', '?position=323',
#        '?position=324', '?position=326', '?position=328', '?position=330',
#        '?position=331', '?position=333', '?position=335', '?position=336',
#        '?position=338', '?position=340', '?position=342', '?position=344',
#        '?position=345', '?position=346', '?position=348', '?position=349',
#        '?position=350', '?position=352', '?position=353', '?position=355',
#        '?position=356', '?position=357', '?position=2', '?position=3',
#        '?position=5', '?position=7', '?position=9', '?position=10',
#        '?position=11', '?position=13', '?position=16', '?position=17',
#        '?position=19', '?position=20', '?position=21', '?position=23',
#        '?position=24', '?position=25', '?position=26', '?position=28',
#        '?position=29', '?position=31', '?position=33', '?position=36',
#        '?position=38', '?position=39', '?position=40', '?position=42',
#        '?position=44', '?position=45', '?position=46', '?position=48',
#        '?position=49', '?position=50', '?position=51', '?position=52',
#        '?position=53', '?position=55', '?position=56', '?position=57',
#        '?position=58', '?position=60', '?position=61', '?position=62',
#        '?position=63', '?position=64', '?position=65', '?position=66',
#        '?position=69', '?position=70', '?position=72', '?position=74',
#        '?position=75', '?position=76', '?position=79', '?position=80',
#        '?position=83', '?position=84', '?position=85', '?position=86',
#        '?position=88', '?position=90', '?position=91', '?position=92',
#        '?position=93', '?position=95', '?position=96', '?position=97',
#        '?position=98', '?position=101', '?position=103', '?position=105',
#        '?position=108', '?position=110', '?position=113', '?position=116',
#        '?position=118', '?position=119', '?position=120', '?position=122',
#        '?position=124', '?position=125', '?position=128', '?position=130',
#        '?position=132', '?position=134', '?position=136', '?position=138',
#        '?position=140', '?position=142', '?position=143', '?position=144',
#        '?position=145', '?position=146', '?position=150', '?position=152',
#        '?position=154', '?position=156', '?position=157', '?position=159',
#        '?position=160', '?position=162', '?position=163', '?position=166',
#        '?position=167', '?position=169', '?position=172', '?position=174',
#        '?position=176', '?position=178', '?position=180', '?position=183',
#        '?position=191', '?position=221', '?position=225', '?position=227',
#        '?position=229', '?position=231', '?position=233', '?position=235',
#        '?position=237', '?position=239', '?position=241', '?position=243',
#        '?position=244', '?position=245', '?position=247', '?position=249',
#        '?position=250', '?position=251', '?position=253', '?position=255',
#        '?position=257', '?position=259', '?position=261', '?position=262',
#        '?position=263', '?position=265', '?position=267', '?position=269',
#        '?position=271', '?position=273', '?position=274', '?position=275',
#        '?position=276', '?position=277', '?position=278', '?position=279',
#        '?position=281', '?position=283'], dtype='<U32')

# %%
# Out:
# array([1., 1., 2., 3., 1., 2., 3., 1.])

# %%
# Out:
# array([ True, False])

# %%
# Out:
# array([4])
