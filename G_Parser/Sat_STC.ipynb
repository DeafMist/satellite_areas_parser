# %%
import requests

headers = {
    'authority': 'genmap.lyngsat.org',
    'accept': 'application/json, text/plain, */*',
    'accept-language': 'ru-RU,ru;q=0.9,en-US;q=0.8,en;q=0.7',
    'referer': 'https://genmap.lyngsat.org/client/public/map/Galaxy-30-North-America////info/zoomed',
    'sec-ch-ua': '"Chromium";v="110", "Not A(Brand";v="24", "Google Chrome";v="110"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/110.0.0.0 Safari/537.36',
}

response = requests.get('https://genmap.lyngsat.org/server2/kml', headers=headers)

# %%
response.json()
# Out:
# {'kml_list': [{'id': '3950802',
#    'name': 'ABS-2-East-hemi',
#    'satpos': '75',
#    'beams_process_timestamp': '1488233895',
#    'url': 'http://genmap.lyngsat.org/server2/kml/getkml/3950802/?ts=1488233895'},
#   {'id': '3950803',
#    'name': 'ABS-2-Global',
#    'satpos': '75',
#    'beams_process_timestamp': '1488209416',
#    'url': 'http://genmap.lyngsat.org/server2/kml/getkml/3950803/?ts=1488209416'},
#   {'id': '3950809',
#    'name': 'ABS-2-Korea-and-SE-Asia',
#    'satpos': '75',
#    'beams_process_timestamp': '1474030925',
#    'url': 'http://genmap.lyngsat.org/server2/kml/getkml/3950809/?ts=1474030925'},
#   {'id': '3950804',
#    'name': 'ABS-2-Russia',
#    'satpos': '75',
#    'beams_process_timestamp': '1471618269',
#    'url': 'http://genmap.lyngsat.org/server2/kml/getkml/3950804/?ts=1471618269'},
#   {'id': '3950810',
#    'name': 'ABS-2-South-Asia',
#    'satpos': '75',
#    'beams_process_timestamp': '1491321736',
# ...

# %%
sattelites = {}

for part in response.json()['kml_list']:
    sattelites[part['name']] = part['url']

# %%
sattelites
# Out:
# {'ABS-2-East-hemi': 'http://genmap.lyngsat.org/server2/kml/getkml/3950802/?ts=1488233895',
#  'ABS-2-Global': 'http://genmap.lyngsat.org/server2/kml/getkml/3950803/?ts=1488209416',
#  'ABS-2-Korea-and-SE-Asia': 'http://genmap.lyngsat.org/server2/kml/getkml/3950809/?ts=1474030925',
#  'ABS-2-Russia': 'http://genmap.lyngsat.org/server2/kml/getkml/3950804/?ts=1471618269',
#  'ABS-2-South-Asia': 'http://genmap.lyngsat.org/server2/kml/getkml/3950810/?ts=1491321736',
#  'ABS-2-Southern': 'http://genmap.lyngsat.org/server2/kml/getkml/3950806/?ts=1463423058',
#  'ABS-2-West-hemi': 'http://genmap.lyngsat.org/server2/kml/getkml/3950801/?ts=1462053257',
#  'ABS-2A-Russia': 'http://genmap.lyngsat.org/server2/kml/getkml/4158801/?ts=1506627616',
#  'ABS-3A-East-hemi': 'http://genmap.lyngsat.org/server2/kml/getkml/4042401/?ts=1488201255',
#  'ABS-3A-SAF': 'http://genmap.lyngsat.org/server2/kml/getkml/4042408/?ts=1524857776',
# ...

# %%
import urllib.request 
print('Beginning file download with urllib2...') 
folder = '/Users/glebk/sat/'
for sat in sattelites.keys():
    url = sattelites[sat]
    if requests.get(url).status_code != 404:
        urllib.request.urlretrieve(url, folder + f'{sat}'+ '.kml')
    else:
        print(sat)
# url = 'http://genmap.lyngsat.org/server2/kml/getkml/2893514/?ts=1460262377' 
# urllib.request.urlretrieve(url, '/Users/glebk/EchoStar-10-Spot-14.kml')
# Out:
# Beginning file download with urllib2...
# Telstar-14R-Southern-Cone

# %%
requests.get('http://genmap.lyngsat.org/server2/kml/getkml/3808707/?ts=1460242264').status_code
# Out:
# 200
